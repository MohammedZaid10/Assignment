# %%
import json
import time

# %%
i={}

# %%
x=input('Import Master Database yes/no:')
if(x=='yes'):
        print('Loading master database in i')
        with open('dataset-json','r') as masteropen:
              data_load=json.load(masteropen)
        i=data_load
        print('Master database has been loaded')
        print(i)
# Out:
# Import Master Database yes/no:no

# %%
x=input('Enter for 1 to create,2 to read,3 for delete,4 to show data,5 to exit:')
if(x==1): 
    class my_dictionary(i):
        def __init__(self):  
            self = dict()   
        def add(self, key, value):  
            self[key] = value   
    dict_obj = my_dictionary() 
    dict_obj.key = input("Enter the key: ") 
    dict_obj.value = input("Enter the value: ") 
    dict_obj.add(dict_obj.key, dict_obj.value)      
if(x==2):
    class my_dictionary(i):
        def __init__(self):  
            self = dict()   
        def add(self, key, value):  
            self[key] = value   
    dict_obj = my_dictionary()
    dict_obj.key=input('Enter key to read')
    print(read(str(dict_obj.key)))
if(x==3):
    class my_dictionary(i):
        def __init__(self):  
            self = dict()   
        def add(self, key, value):  
            self[key] = value   
    dict_obj = my_dictionary() 
    dict_obj.key=Input('Enter Key')
    dict_obj.pop(dict_obj.key, None)
    print('key deleted')
if(x==4):
    print(d)
if(x==5):
    exit()
# Out:
# Enter for 1 to create,2 to read,3 for delete,4 to show data,5 to exit:5

# %%
d=i
def read(k):
    if k not in d:
        print ("Error: This key is not present")
    else:
        b=d[k]
        if b[1]!=0:
            if time.time ()<b[1]:
                stri=str(k)+":"+str(b[0])
                return stri
            else:
                print ("Error: time-to-live of",k, "has expired")
        exit()

# %%
import json
i=d
with open('i.json','w') as fp:
    json.dump(i,fp)

print('Your database after operations are :')
print(i)
# Out:
# Your database after operations are :
# {}

# %%
x=input('Is this first ever operation yes/no')
if(x=='yes'):
    with open('datset.json','w') as fp:
        json.dump (i, fp)
    print("thank you")
    exit()
# Out:
# Is this first ever operation yes/nono

# %%
x=input('Do you want to save this is as the master dataset yes/no :')
if(x=='yes'):
    data={}
    import json
    with open('datset.json', 'r') as fp:
        data =json.load(fp)
    master=dict(data)
    master.update(i)
    with open('datset.json', 'w') as fp:
        json.dump (master,fp)
print('All task done thanks')
# Out:
# Do you want to save this is as the master dataset yes/no :no
# All task done thanks
